# %%
from typing import List

from copy import copy, deepcopy
import numpy as np

class Puzzle_Position(object):
    def __init__(self, value, goal):
        self.value = value
        self.goal = goal
    def __repr__(self):
        return "{}".format(self.value)
    def __str__(self):
        return "{}".format(self.value)

class Puzzle(object):
    def __init__(self, matrix=List[List[int]]):
        self._matrix = [[Puzzle_Position(l[0], (3*i)+0),
                         Puzzle_Position(l[1], (3*i)+1),
                         Puzzle_Position(l[2], (3*i)+2)]  for i, l in enumerate(matrix)]
    
    def __eq__(self, other):
        if type(other) == type(self):
            for i, list in enumerate(self._matrix):
                for j, el in enumerate(list):
                    if el.value != other._matrix[i][j].value:
                        return False
            
            return True
        
        else:
            return False
    
    def show_matrix(self):
        for i in self._matrix:
            print("|", end='')
            for j in i:
                print(j, end='')
            print("|")

    def move_up(self, x, y):
        try:
            if self._matrix[x-1][y].value == 0:
                self._matrix[x-1][y].value = self._matrix[x][y].value
                self._matrix[x][y].value = 0
                return True
            else:
                print("The goal position is not 0!")
                return False
            

        except IndexError:
            print("Movement not allowed!")
            return False

    def move_down(self, x, y):
        try:
            if self._matrix[x+1][y].value == 0:
                self._matrix[x+1][y].value = self._matrix[x][y].value
                self._matrix[x][y].value = 0
                return True
            else:
                print("The goal position is not 0!")
                return False
        except IndexError:
            print("MOvement not allowed!")
            return False
    
    def move_right(self, x, y):
        try:
            if self._matrix[x][y+1].value == 0:
                self._matrix[x][y+1].value = self._matrix[x][y].value
                self._matrix[x][y].value = 0
                return True
            else:
                print("The goal position is not 0!")
                return False
        except IndexError:
            print("MOvement not allowed!")
            return False
    
    def move_left(self, x, y):
        try:
            if self._matrix[x][y-1].value == 0:
                self._matrix[x][y-1].value = self._matrix[x][y].value
                self._matrix[x][y].value = 0
                return True
            else:
                print("The goal position is not 0!")
                return False
        except IndexError:
            print("MOvement not allowed!")
            return False
        
class SolvePuzzle(object):
    def __init__(self, puzzle: Puzzle):
        self.puzzle = puzzle
        self.movements = []
        self.empty_position = self.get_empty_position()
        self.visited = []
    
    def get_empty_position(self) -> List:
        for i, il in enumerate(self.puzzle._matrix):
            for j, el in enumerate(il):
                if el.value == 0:
                    return i, j
    
    def get_dif_goal(self, puzzle=None) -> List:
        diff_values = []
        if not puzzle:
            puzzle = self.puzzle
        for i in puzzle._matrix:
            for j in i:
                if j.goal != j.value:
                    diff_values.append((j.value, j.goal))
        
        return diff_values
    
    def change_right(self):
        puzzle = deepcopy(self.puzzle)
        if puzzle.move_left(self.empty_position[0], self.empty_position[1]+1):
            return (puzzle, 'left')
        else:
            return False
        
    def change_left(self):
        puzzle = deepcopy(self.puzzle)
        if puzzle.move_right(self.empty_position[0], self.empty_position[1]-1):
            return (puzzle, 'right')
        else:
            return False
    
    def change_down(self):
        puzzle = deepcopy(self.puzzle)
        if puzzle.move_up(self.empty_position[0]+1, self.empty_position[1]):
            return (puzzle, 'down')
        else:
            return False
    
    def change_up(self):
        puzzle = deepcopy(self.puzzle)
        if puzzle.move_down(self.empty_position[0]-1, self.empty_position[1]):
            return (puzzle, 'up')
        else:
            return False
    
    def calculate_diffs(self, puzzle):
        diffs = self.get_dif_goal(puzzle)
        amount_diff = 0
        for d in diffs:
            amount_diff+= abs(d[1]-d[0])
        
        return amount_diff

    def run(self):
        while self.get_dif_goal() != []:

            childs = np.array([
                self.change_up() if self.change_up() else (False, False), 
                self.change_down() if self.change_down() else (False, False), 
                self.change_left() if self.change_left() else (False, False),
                self.change_right() if self.change_right() else (False, False)])

            # print(self.calculate_diffs(self.change_up()[0]) if self.change_up() else int(100000))
            # print(self.calculate_diffs(self.change_down()[0]) if self.change_down() else int(100000))
            # print(self.calculate_diffs(self.change_left()[0]) if self.change_left() else int(100000))
            # print(self.calculate_diffs(self.change_right()[0]) if self.change_right() else int(100000))

            childs_diff = np.array([
                self.calculate_diffs(self.change_up()[0]) if self.change_up() else int(100000), 
                self.calculate_diffs(self.change_down()[0]) if self.change_down() else int(100000), 
                self.calculate_diffs(self.change_left()[0]) if self.change_left() else int(100000), 
                self.calculate_diffs(self.change_right()[0]) if self.change_right() else int(100000)])

            near_goal_order_index = np.argsort(childs_diff)

            near_child_goal = childs[near_goal_order_index]

            for child_goal in near_child_goal:

                if child_goal[0] not in self.visited:

                    self.puzzle = child_goal[0]
                    self.empty_position = self.get_empty_position()
                    self.movements.append([child_goal[1]])
                    self.visited.append(child_goal[0])
                    break

# %%
matrix = [
    [7,2,4],
    [5,0,6],
    [8,3,1]
]

# matrix = [
#     [0,1,2],
#     [3,4,5],
#     [6,7,8]
# ]


p_obj = Puzzle(matrix=matrix)

s_obj = SolvePuzzle(p_obj)

# %%
s_obj.get_dif_goal()
# Out:
# [(7, 0), (2, 1), (4, 2), (5, 3), (0, 4), (6, 5), (8, 6), (3, 7), (1, 8)]

# %%
s_obj.puzzle.show_matrix()
# Out:
# |724|
# |506|
# |831|

# %%
s_obj.run()
# Out:
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c943afe20> 'up']
#  [<__main__.Puzzle object at 0x7f9c943ab790> 'right']
#  [<__main__.Puzzle object at 0x7f9c943b9cd0> 'down']
#  [<__main__.Puzzle object at 0x7f9c943aff70> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c97474130> 'right']
#  [<__main__.Puzzle object at 0x7f9c943ca610> 'down']
#  [<__main__.Puzzle object at 0x7f9c943b93d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c94361af0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c94361cd0> 'left']
#  [<__main__.Puzzle object at 0x7f9c943d7310> 'right']
#  [<__main__.Puzzle object at 0x7f9c97822820> 'down']
#  [<__main__.Puzzle object at 0x7f9c943aff70> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c94361c40> 'right']
#  [<__main__.Puzzle object at 0x7f9c94354b20> 'up']
#  [<__main__.Puzzle object at 0x7f9c943ab1c0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c94354730> 'right']
#  [<__main__.Puzzle object at 0x7f9c943f8c40> 'down']
#  [<__main__.Puzzle object at 0x7f9c943ad250> 'left']
#  [<__main__.Puzzle object at 0x7f9c94354fa0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c9434b370> 'left']
#  [<__main__.Puzzle object at 0x7f9c94361280> 'right']
#  [<__main__.Puzzle object at 0x7f9c94354b20> 'down']
#  [<__main__.Puzzle object at 0x7f9c943612b0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c97470070> 'right']
#  [<__main__.Puzzle object at 0x7f9c943ab370> 'up']
#  [<__main__.Puzzle object at 0x7f9c943427f0> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c943afd30> 'up']
#  [<__main__.Puzzle object at 0x7f9c9434b9a0> 'right']
#  [False False]
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c94342790> 'up']
#  [<__main__.Puzzle object at 0x7f9c94341460> 'right']
#  [<__main__.Puzzle object at 0x7f9c943a7160> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847d61f0> 'right']
#  [<__main__.Puzzle object at 0x7f9c943423a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847d4040> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847d3160> 'right']
#  [<__main__.Puzzle object at 0x7f9c847d6fd0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847d87f0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847d4ca0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c943423a0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847db280> 'right']
#  [<__main__.Puzzle object at 0x7f9c847d5d90> 'down']
#  [<__main__.Puzzle object at 0x7f9c847d5e80> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847dcc10> 'right']
#  [<__main__.Puzzle object at 0x7f9c847da400> 'down']
#  [<__main__.Puzzle object at 0x7f9c847da220> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ce670> 'right']
#  [<__main__.Puzzle object at 0x7f9c847dedf0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847d8f70> 'left']
#  [<__main__.Puzzle object at 0x7f9c847d5f70> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e20a0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e1730> 'right']
#  [<__main__.Puzzle object at 0x7f9c847d7f40> 'down']
#  [<__main__.Puzzle object at 0x7f9c847da310> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847d6160> 'up']
#  [<__main__.Puzzle object at 0x7f9c847dedf0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847dc880> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e07f0> 'down']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e1730> 'up']
#  [<__main__.Puzzle object at 0x7f9c847d8640> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e0d90> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847dc9d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847d66a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847d6160> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847df4f0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847d62b0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e0a60> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e0d90> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e0160> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e0580> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e06d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847db0a0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847d62b0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e3970> 'left']
#  [<__main__.Puzzle object at 0x7f9c847d8ee0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847d8640> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847db0a0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847d84c0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e0370> 'right']
#  [<__main__.Puzzle object at 0x7f9c847dfb20> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e0610> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e0f70> 'left']
#  [<__main__.Puzzle object at 0x7f9c847da310> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e3a00> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847dfb20> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e0a60> 'down']
#  [<__main__.Puzzle object at 0x7f9c847d8f70> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e0370> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847d62b0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e3b80> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e3bb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e3850> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847dba60> 'right']
#  [<__main__.Puzzle object at 0x7f9c847d8f70> 'up']
#  [<__main__.Puzzle object at 0x7f9c847d81f0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847dfb20> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847df640> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e3fa0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e39d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e0460> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e3850> 'left']
#  [<__main__.Puzzle object at 0x7f9c847d84c0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847dfb20> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e3a30> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e3fa0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e3b50> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e2d90> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e6ee0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e6f40> 'down']
#  [<__main__.Puzzle object at 0x7f9c847dba60> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e6340> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e77f0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e6d90> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e7af0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e6e50> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e6df0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e6f10> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e79d0> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847da5b0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ded30> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e6340> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e6250> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e6df0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e7700> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e3a30> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e9d90> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e9a90> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e0580> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e9a00> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e9e20> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e9f10> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e9ee0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e6340> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e9a00> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e9a90> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e0f70> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e9250> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e9220> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e6340> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e92b0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e3b50> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e3df0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e3ac0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e7f10> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e6e50> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e6e20> 'down']
#  [<__main__.Puzzle object at 0x7f9c847eb1f0> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e9e20> 'up']
#  [<__main__.Puzzle object at 0x7f9c847eb520> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ebdc0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847eb1f0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ebf10> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e6e50> 'down']
#  [<__main__.Puzzle object at 0x7f9c847eb9d0> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ebd90> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e9370> 'left']
#  [<__main__.Puzzle object at 0x7f9c847d8ee0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e9e20> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e9a90> 'right']
#  [<__main__.Puzzle object at 0x7f9c847eccd0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e6280> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ebd00> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ecfd0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ecdc0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847d8640> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ec430> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ec8b0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e6e50> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ebf10> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ec820> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ec0d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ecc70> 'down']
#  [<__main__.Puzzle object at 0x7f9c847d8640> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ec1c0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e6280> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ebf10> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847d8640> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ec820> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ecc70> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847eb9d0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ecca0> 'right']
#  [False False]
#  [False False]]
# Movement not allowed!
# Movement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ecee0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e3a00> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e0580> 'left']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ea850> 'right']
#  [<__main__.Puzzle object at 0x7f9c847d8640> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ec400> 'left']
#  [<__main__.Puzzle object at 0x7f9c847e2730> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f0e50> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f0760> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f0df0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e3b50> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f1790> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ecf70> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ec3d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847e2730> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ec820> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ec280> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f0eb0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f0940> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e3b50> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ebf10> 'up']
#  [<__main__.Puzzle object at 0x7f9c847e2730> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e3a00> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f0970> 'right']
#  [False False]
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e2730> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ecf70> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ecbe0> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f1c10> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f1a90> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f09a0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f18b0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f1160> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f1220> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e7f10> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f2b80> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f2af0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f2a30> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ecc40> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f0760> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f0fd0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f0d30> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f11c0> 'down']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f1f10> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f2970> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f1b20> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f0760> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3580> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f0d30> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f1dc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f1a30> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f16a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f3940> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f1d00> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f1130> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f1940> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f2040> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f3fa0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3dc0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847e7f10> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f1670> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f1160> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f1af0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f2b50> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f38b0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f3eb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3f10> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f16d0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f2d30> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f1a00> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f1af0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f1d30> 'down']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f1130> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f1910> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f1fd0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f8c70> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f2100> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f8640> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f1160> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f3e80> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f1700> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f4dc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f4d30> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f3f70> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f3550> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3910> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8fa0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f8730> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f4dc0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f8a30> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f85b0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847e7f10> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3a60> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f0d30> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f3a30> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f9d00> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3580> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f8640> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f9460> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9220> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f3940> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f89d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f8af0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8a60> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f3580> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847fb7f0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f4df0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f4f10> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f4e80> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f98b0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9490> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8af0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f9d60> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f96d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f97c0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8a30> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f9610> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9ac0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f9c10> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8f40> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f9e20> 'right']
#  [<__main__.Puzzle object at 0x7f9c847fbbe0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8a30> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f89a0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f8a60> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f8730> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847fddf0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f96d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9790> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f9550> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f85b0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3a30> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f3eb0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8730> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f85e0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f9eb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9880> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f9550> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847fdeb0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847fb880> 'right']
#  [<__main__.Puzzle object at 0x7f9c847fbfa0> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847fbf70> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f8c40> 'up']
#  [<__main__.Puzzle object at 0x7f9c847fb7f0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847fda00> 'up']
#  [<__main__.Puzzle object at 0x7f9c847fd9d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9d90> 'left']
#  [<__main__.Puzzle object at 0x7f9c847fb8e0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84782f10> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9910> 'down']
#  [<__main__.Puzzle object at 0x7f9c84782eb0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f3550> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84782c40> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f9a00> 'right']
#  [<__main__.Puzzle object at 0x7f9c847fd160> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f9b50> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84782eb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3940> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f92b0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84782910> 'right']
#  [<__main__.Puzzle object at 0x7f9c84782e20> 'down']
#  [<__main__.Puzzle object at 0x7f9c84782940> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f9b50> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84785f40> 'left']
#  [<__main__.Puzzle object at 0x7f9c84785fa0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84782a90> 'down']
#  [<__main__.Puzzle object at 0x7f9c847fbcd0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847821c0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3eb0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84782100> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8477f640> 'up']
#  [<__main__.Puzzle object at 0x7f9c84782250> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f96d0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84785d00> 'up']
#  [<__main__.Puzzle object at 0x7f9c84782a00> 'right']
#  [<__main__.Puzzle object at 0x7f9c84782190> 'left']
#  [<__main__.Puzzle object at 0x7f9c84782a60> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847fbcd0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f3940> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f9550> 'left']
#  [<__main__.Puzzle object at 0x7f9c8477f940> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84787610> 'left']
#  [<__main__.Puzzle object at 0x7f9c847875e0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847821c0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84782040> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84787fa0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847878e0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84785e50> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84785760> 'right']
#  [<__main__.Puzzle object at 0x7f9c84785b20> 'down']
#  [<__main__.Puzzle object at 0x7f9c84785bb0> 'left']
#  [<__main__.Puzzle object at 0x7f9c84782a60> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84789f70> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f9550> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9790> 'down']
#  [<__main__.Puzzle object at 0x7f9c847fb8e0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f97f0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847fb7f0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84785f10> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84785d60> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f9b50> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f9be0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84789880> 'up']
#  [<__main__.Puzzle object at 0x7f9c84787910> 'right']
#  [<__main__.Puzzle object at 0x7f9c84787be0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847876a0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8477f8e0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8477f760> 'left']
#  [<__main__.Puzzle object at 0x7f9c8477fb20> 'down']
#  [<__main__.Puzzle object at 0x7f9c84782e20> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847899a0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84785b20> 'left']
#  [<__main__.Puzzle object at 0x7f9c847f96a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84789fd0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8477fb20> 'right']
#  [<__main__.Puzzle object at 0x7f9c8477f670> 'down']
#  [<__main__.Puzzle object at 0x7f9c84785f40> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f92b0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847f97f0> 'up']
#  [<__main__.Puzzle object at 0x7f9c84785f10> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84789f10> 'up']
#  [<__main__.Puzzle object at 0x7f9c847fb8e0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8478be50> 'left']
#  [<__main__.Puzzle object at 0x7f9c84782e20> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f3a30> 'up']
#  [<__main__.Puzzle object at 0x7f9c8478eee0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8478bdc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8478be80> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847f9460> 'down']
#  [<__main__.Puzzle object at 0x7f9c8478be50> 'left']
#  [<__main__.Puzzle object at 0x7f9c8478bdf0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8478e1c0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8478b970> 'right']
#  [<__main__.Puzzle object at 0x7f9c84785310> 'left']
#  [<__main__.Puzzle object at 0x7f9c84785f10> 'down']
#  [<__main__.Puzzle object at 0x7f9c8478ee80> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8478bd30> 'right']
#  [<__main__.Puzzle object at 0x7f9c8477fd30> 'down']
#  [<__main__.Puzzle object at 0x7f9c8477f730> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8478ea90> 'up']
#  [<__main__.Puzzle object at 0x7f9c847f9880> 'right']
#  [<__main__.Puzzle object at 0x7f9c84785b20> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84782a30> 'up']
#  [<__main__.Puzzle object at 0x7f9c8478edc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8477fa60> 'left']
#  [<__main__.Puzzle object at 0x7f9c8478e2b0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8477fac0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8477fa90> 'down']
#  [<__main__.Puzzle object at 0x7f9c8477f940> 'left']
#  [<__main__.Puzzle object at 0x7f9c8478bdf0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8477fa60> 'down']
#  [<__main__.Puzzle object at 0x7f9c8477fe50> 'left']
#  [<__main__.Puzzle object at 0x7f9c84790dc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8478eaf0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8478b760> 'up']
#  [<__main__.Puzzle object at 0x7f9c847900a0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84793a90> 'left']
#  [<__main__.Puzzle object at 0x7f9c847900d0> 'down']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84782040> 'up']
#  [<__main__.Puzzle object at 0x7f9c8477fe50> 'right']
#  [<__main__.Puzzle object at 0x7f9c847821f0> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84793d90> 'right']
#  [<__main__.Puzzle object at 0x7f9c84793a90> 'down']
#  [<__main__.Puzzle object at 0x7f9c847895e0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8477fa90> 'right']
#  [<__main__.Puzzle object at 0x7f9c84785eb0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84793f40> 'left']
#  [<__main__.Puzzle object at 0x7f9c84782e20> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84782190> 'left']
#  [<__main__.Puzzle object at 0x7f9c84790160> 'right']
#  [<__main__.Puzzle object at 0x7f9c84790040> 'down']
#  [<__main__.Puzzle object at 0x7f9c84789df0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84785f10> 'right']
#  [<__main__.Puzzle object at 0x7f9c84796a60> 'down']
#  [<__main__.Puzzle object at 0x7f9c84796fd0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84789df0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84790e80> 'left']
#  [<__main__.Puzzle object at 0x7f9c847900d0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8f40> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84796250> 'right']
#  [<__main__.Puzzle object at 0x7f9c84796940> 'left']
#  [<__main__.Puzzle object at 0x7f9c84796070> 'down']
#  [<__main__.Puzzle object at 0x7f9c84793070> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8477f7c0> 'up']
#  [<__main__.Puzzle object at 0x7f9c84796eb0> 'left']
#  [<__main__.Puzzle object at 0x7f9c84785eb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84793400> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84796940> 'up']
#  [<__main__.Puzzle object at 0x7f9c847966a0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84796880> 'left']
#  [<__main__.Puzzle object at 0x7f9c84796b80> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847900d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84793a90> 'left']
#  [<__main__.Puzzle object at 0x7f9c847969d0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8477f940> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8478b970> 'right']
#  [<__main__.Puzzle object at 0x7f9c84796880> 'left']
#  [<__main__.Puzzle object at 0x7f9c84790e80> 'down']
#  [<__main__.Puzzle object at 0x7f9c84796b80> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84796b50> 'right']
#  [<__main__.Puzzle object at 0x7f9c84796f10> 'down']
#  [<__main__.Puzzle object at 0x7f9c84789eb0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479be50> 'right']
#  [<__main__.Puzzle object at 0x7f9c847969d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c84790e80> 'down']
#  [<__main__.Puzzle object at 0x7f9c84798d30> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479ba30> 'left']
#  [<__main__.Puzzle object at 0x7f9c8479ba90> 'down']
#  [<__main__.Puzzle object at 0x7f9c8478ee50> 'right']
#  [<__main__.Puzzle object at 0x7f9c84793a90> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8478ee80> 'up']
#  [<__main__.Puzzle object at 0x7f9c847987f0> 'left']
#  [<__main__.Puzzle object at 0x7f9c84798880> 'right']
#  [<__main__.Puzzle object at 0x7f9c84793400> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84796520> 'right']
#  [<__main__.Puzzle object at 0x7f9c8477f7c0> 'up']
#  [<__main__.Puzzle object at 0x7f9c8479b520> 'left']
#  [<__main__.Puzzle object at 0x7f9c847895e0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84798d90> 'right']
#  [<__main__.Puzzle object at 0x7f9c84798e20> 'down']
#  [<__main__.Puzzle object at 0x7f9c84798ca0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8479bbe0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479ba30> 'left']
#  [<__main__.Puzzle object at 0x7f9c84798cd0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479b520> 'down']
#  [<__main__.Puzzle object at 0x7f9c847f8f40> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84789eb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479d9a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8479d970> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479b520> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479bbe0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847969d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8479d430> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479fd60> 'left']
#  [<__main__.Puzzle object at 0x7f9c8479fdc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479bc70> 'down']
#  [<__main__.Puzzle object at 0x7f9c84790e80> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479fbe0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479bdf0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84798d00> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8478efd0> 'up']
#  [<__main__.Puzzle object at 0x7f9c8479d9a0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84793a90> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8478ed60> 'up']
#  [<__main__.Puzzle object at 0x7f9c8479fa00> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479f910> 'left']
#  [<__main__.Puzzle object at 0x7f9c8479f8e0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a1880> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a1fa0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8479fa30> 'down']
#  [<__main__.Puzzle object at 0x7f9c84793a90> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a15e0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847a1640> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479feb0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8479fd90> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a1f40> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a1ee0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8479bc70> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479feb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479fa00> 'left']
#  [<__main__.Puzzle object at 0x7f9c8479fc70> 'down']
#  [<__main__.Puzzle object at 0x7f9c8479f910> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a1b80> 'left']
#  [<__main__.Puzzle object at 0x7f9c847a1a00> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a1eb0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847895e0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a15e0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a1f70> 'down']
#  [<__main__.Puzzle object at 0x7f9c8479d310> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479bc70> 'up']
#  [<__main__.Puzzle object at 0x7f9c847895e0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a3e80> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a1c70> 'up']
#  [<__main__.Puzzle object at 0x7f9c847a3a90> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a1a90> 'left']
#  [<__main__.Puzzle object at 0x7f9c847a1ac0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a15b0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a1be0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8479ba30> 'down']
#  [<__main__.Puzzle object at 0x7f9c847a1b50> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a1ac0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a37f0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847a3af0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847a1a90> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a1be0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a6ee0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847a3e80> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a6970> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a6a90> 'left']
#  [<__main__.Puzzle object at 0x7f9c847a69d0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847a34f0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84798940> 'left']
#  [<__main__.Puzzle object at 0x7f9c847a6ee0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84798b80> 'down']
#  [<__main__.Puzzle object at 0x7f9c8479f9d0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a69d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a6880> 'down']
#  [<__main__.Puzzle object at 0x7f9c847a34f0> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479ba60> 'up']
#  [<__main__.Puzzle object at 0x7f9c847a6940> 'right']
#  [<__main__.Puzzle object at 0x7f9c8479ba30> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a1100> 'up']
#  [<__main__.Puzzle object at 0x7f9c847a1af0> 'right']
#  [False False]
#  [False False]]
# Movement not allowed!
# Movement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84798d30> 'up']
#  [<__main__.Puzzle object at 0x7f9c84798b80> 'right']
#  [<__main__.Puzzle object at 0x7f9c84798d00> 'left']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a98e0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a98b0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847a9940> 'down']
#  [<__main__.Puzzle object at 0x7f9c847a3a90> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a97f0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847a9e80> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ab4f0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a9e50> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8479bc70> 'left']
#  [<__main__.Puzzle object at 0x7f9c847a98b0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847a9640> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a9850> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847abd90> 'right']
#  [<__main__.Puzzle object at 0x7f9c847adee0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ab250> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ab0a0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a98b0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a1100> 'down']
#  [<__main__.Puzzle object at 0x7f9c84798ac0> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ab550> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ad640> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ab4c0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847abe80> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ab160> 'right']
#  [<__main__.Puzzle object at 0x7f9c847a3b50> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ab910> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847abe20> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ab0a0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ab820> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ad430> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847af100> 'left']
#  [<__main__.Puzzle object at 0x7f9c847add60> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ab910> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ab2b0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a9e80> 'up']
#  [<__main__.Puzzle object at 0x7f9c847afd00> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ab550> 'right']
#  [<__main__.Puzzle object at 0x7f9c84798880> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ade20> 'up']
#  [<__main__.Puzzle object at 0x7f9c847af3a0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847afb80> 'left']
#  [<__main__.Puzzle object at 0x7f9c847af3d0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a9eb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ab4c0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847af9d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ad490> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847a9850> 'left']
#  [<__main__.Puzzle object at 0x7f9c847b21f0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847af4f0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847af100> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ad490> 'right']
#  [<__main__.Puzzle object at 0x7f9c84798880> 'down']
#  [<__main__.Puzzle object at 0x7f9c847b2d30> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ad700> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ad5e0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847af910> 'left']
#  [<__main__.Puzzle object at 0x7f9c847b2730> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ad3a0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ad190> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ab250> 'down']
#  [<__main__.Puzzle object at 0x7f9c847addf0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b2820> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ad730> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ad370> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847addf0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ad160> 'right']
#  [<__main__.Puzzle object at 0x7f9c847af9d0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ad310> 'up']
#  [<__main__.Puzzle object at 0x7f9c847af370> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ad370> 'left']
#  [<__main__.Puzzle object at 0x7f9c847a3ac0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4e50> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b4b20> 'left']
#  [<__main__.Puzzle object at 0x7f9c847b4a00> 'down']
#  [<__main__.Puzzle object at 0x7f9c847abd90> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b43a0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ad370> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b2850> 'down']
#  [<__main__.Puzzle object at 0x7f9c847b4f70> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ab820> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ab880> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ad130> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ab0d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ab070> 'left']
#  [<__main__.Puzzle object at 0x7f9c847b72e0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847b2e50> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ab880> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ad400> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b79d0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847b2bb0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4af0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847addf0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ab250> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4fd0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84798880> 'up']
#  [<__main__.Puzzle object at 0x7f9c847b4fa0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4ac0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847bae80> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b4df0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847bafa0> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847bac40> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ba910> 'left']
#  [<__main__.Puzzle object at 0x7f9c847ba9a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847af9d0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4310> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b42b0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847b4f40> 'down']
#  [<__main__.Puzzle object at 0x7f9c847b4df0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847af370> 'right']
#  [<__main__.Puzzle object at 0x7f9c847baf70> 'down']
#  [<__main__.Puzzle object at 0x7f9c847af9d0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4df0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b4f40> 'left']
#  [<__main__.Puzzle object at 0x7f9c847b4e20> 'down']
#  [<__main__.Puzzle object at 0x7f9c847ba2b0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4a60> 'left']
#  [<__main__.Puzzle object at 0x7f9c847bc820> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b4fa0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847b7ee0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ba220> 'right']
#  [<__main__.Puzzle object at 0x7f9c847bc0d0> 'down']
#  [<__main__.Puzzle object at 0x7f9c847bc070> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847baf70> 'up']
#  [<__main__.Puzzle object at 0x7f9c847b4e20> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b44c0> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4f70> 'up']
#  [<__main__.Puzzle object at 0x7f9c847ba2e0> 'right']
#  [False False]
#  [False False]]
# Movement not allowed!
# Movement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847baf70> 'right']
#  [<__main__.Puzzle object at 0x7f9c847bc7c0> 'up']
#  [<__main__.Puzzle object at 0x7f9c847b27f0> 'left']
#  [False False]]
# Movement not allowed!
# Movement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b4f70> 'up']
#  [<__main__.Puzzle object at 0x7f9c8473ff70> 'right']
#  [<__main__.Puzzle object at 0x7f9c8473fd90> 'left']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b2b80> 'up']
#  [<__main__.Puzzle object at 0x7f9c8473fca0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8473f7c0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8473fbe0> 'right']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847bae50> 'left']
#  [<__main__.Puzzle object at 0x7f9c847bacd0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8473fac0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ba970> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8473feb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8473f7c0> 'left']
#  [<__main__.Puzzle object at 0x7f9c847b2a30> 'down']
#  [<__main__.Puzzle object at 0x7f9c847b2ca0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8473fcd0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847ba970> 'up']
#  [<__main__.Puzzle object at 0x7f9c84741430> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847b2a30> 'up']
#  [<__main__.Puzzle object at 0x7f9c847b2c70> 'right']
#  [False False]
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ba910> 'up']
#  [<__main__.Puzzle object at 0x7f9c847baee0> 'right']
#  [<__main__.Puzzle object at 0x7f9c847b2df0> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84741be0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84741b50> 'down']
#  [<__main__.Puzzle object at 0x7f9c847b2c70> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c847ab880> 'right']
# ...
#  [<__main__.Puzzle object at 0x7f9c84682fd0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84684fa0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84682d00> 'right']
#  [<__main__.Puzzle object at 0x7f9c846829d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c84682520> 'up']
#  [<__main__.Puzzle object at 0x7f9c84682460> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688ca0> 'left']
#  [<__main__.Puzzle object at 0x7f9c84686e50> 'right']
#  [<__main__.Puzzle object at 0x7f9c84686af0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84686a90> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84682af0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84682520> 'down']
#  [<__main__.Puzzle object at 0x7f9c8467f730> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688eb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84684a90> 'up']
#  [<__main__.Puzzle object at 0x7f9c84686af0> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8467f520> 'up']
#  [<__main__.Puzzle object at 0x7f9c84688850> 'right']
#  [<__main__.Puzzle object at 0x7f9c846865b0> 'down']
#  [<__main__.Puzzle object at 0x7f9c846861f0> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846fc880> 'right']
#  [<__main__.Puzzle object at 0x7f9c84688ca0> 'left']
#  [<__main__.Puzzle object at 0x7f9c84684fa0> 'up']
#  [<__main__.Puzzle object at 0x7f9c84686f10> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846884c0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8468b100> 'left']
#  [<__main__.Puzzle object at 0x7f9c846882b0> 'down']
#  [<__main__.Puzzle object at 0x7f9c846861c0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688dc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84688ca0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84684a90> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688f40> 'right']
#  [<__main__.Puzzle object at 0x7f9c84688e50> 'left']
#  [<__main__.Puzzle object at 0x7f9c84686f10> 'up']
#  [<__main__.Puzzle object at 0x7f9c84688d60> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8468b5b0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8468b970> 'right']
#  [<__main__.Puzzle object at 0x7f9c8468b910> 'down']
#  [<__main__.Puzzle object at 0x7f9c84684a90> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8468b070> 'right']
#  [<__main__.Puzzle object at 0x7f9c8468b0a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84688820> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688ca0> 'up']
#  [<__main__.Puzzle object at 0x7f9c84684a00> 'right']
#  [<__main__.Puzzle object at 0x7f9c84686910> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688550> 'up']
#  [<__main__.Puzzle object at 0x7f9c84688820> 'right']
#  [False False]
#  [False False]]
# Movement not allowed!
# Movement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846fcb20> 'up']
#  [<__main__.Puzzle object at 0x7f9c8468b100> 'right']
#  [<__main__.Puzzle object at 0x7f9c84684fd0> 'left']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688e50> 'right']
#  [<__main__.Puzzle object at 0x7f9c8468bcd0> 'up']
#  [<__main__.Puzzle object at 0x7f9c84684f70> 'down']
#  [<__main__.Puzzle object at 0x7f9c84688550> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84684fd0> 'up']
#  [<__main__.Puzzle object at 0x7f9c84684ee0> 'left']
#  [<__main__.Puzzle object at 0x7f9c846fcbb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8468b100> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688ca0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8468b5b0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84688f10> 'right']
#  [<__main__.Puzzle object at 0x7f9c84684fa0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84690040> 'right']
#  [<__main__.Puzzle object at 0x7f9c8468b100> 'left']
#  [<__main__.Puzzle object at 0x7f9c846fc7f0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8468d370> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688670> 'right']
#  [<__main__.Puzzle object at 0x7f9c846846d0> 'up']
#  [<__main__.Puzzle object at 0x7f9c8468b5b0> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846861c0> 'up']
#  [<__main__.Puzzle object at 0x7f9c84684a90> 'right']
#  [False False]
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8468b5b0> 'up']
#  [<__main__.Puzzle object at 0x7f9c846904f0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84688f10> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84690dc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84690f40> 'down']
#  [<__main__.Puzzle object at 0x7f9c846921f0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84690a30> 'right']
#  [<__main__.Puzzle object at 0x7f9c846900d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c84690100> 'down']
#  [<__main__.Puzzle object at 0x7f9c84692580> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84695880> 'left']
#  [<__main__.Puzzle object at 0x7f9c846906a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84695fa0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8468d520> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84684fa0> 'up']
#  [<__main__.Puzzle object at 0x7f9c84688670> 'right']
#  [<__main__.Puzzle object at 0x7f9c84692340> 'left']
#  [<__main__.Puzzle object at 0x7f9c84692df0> 'down']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846903a0> 'up']
#  [<__main__.Puzzle object at 0x7f9c846900a0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84695cd0> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84690370> 'right']
#  [<__main__.Puzzle object at 0x7f9c84690520> 'down']
#  [<__main__.Puzzle object at 0x7f9c84695e20> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84690550> 'right']
#  [<__main__.Puzzle object at 0x7f9c84684a00> 'left']
#  [<__main__.Puzzle object at 0x7f9c84690070> 'down']
#  [<__main__.Puzzle object at 0x7f9c846900a0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84688f10> 'right']
#  [<__main__.Puzzle object at 0x7f9c84697c10> 'left']
#  [<__main__.Puzzle object at 0x7f9c846904f0> 'down']
#  [<__main__.Puzzle object at 0x7f9c846fcbb0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84697d60> 'right']
#  [<__main__.Puzzle object at 0x7f9c84692e20> 'down']
#  [<__main__.Puzzle object at 0x7f9c846924f0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846959d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84695910> 'left']
#  [<__main__.Puzzle object at 0x7f9c846954c0> 'down']
#  [<__main__.Puzzle object at 0x7f9c846904f0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84690070> 'left']
#  [<__main__.Puzzle object at 0x7f9c846902e0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84695e20> 'down']
#  [<__main__.Puzzle object at 0x7f9c84695a00> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84692400> 'up']
#  [<__main__.Puzzle object at 0x7f9c8469aa00> 'left']
#  [<__main__.Puzzle object at 0x7f9c84697c10> 'right']
#  [<__main__.Puzzle object at 0x7f9c84697190> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846902e0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84690520> 'up']
#  [<__main__.Puzzle object at 0x7f9c84697be0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84695a00> 'left']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84692580> 'right']
#  [<__main__.Puzzle object at 0x7f9c84697c10> 'down']
#  [<__main__.Puzzle object at 0x7f9c84692d30> 'left']
#  [<__main__.Puzzle object at 0x7f9c84697c70> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84692430> 'left']
#  [<__main__.Puzzle object at 0x7f9c84690af0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84692df0> 'down']
#  [<__main__.Puzzle object at 0x7f9c846902e0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84692940> 'right']
#  [<__main__.Puzzle object at 0x7f9c84692190> 'down']
#  [<__main__.Puzzle object at 0x7f9c8469a940> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84692460> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469ae20> 'down']
#  [<__main__.Puzzle object at 0x7f9c84692430> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469ad30> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8469a850> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469af70> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469ab80> 'down']
#  [<__main__.Puzzle object at 0x7f9c84692dc0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8469cee0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469c790> 'down']
#  [<__main__.Puzzle object at 0x7f9c8469c970> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84692a90> 'up']
#  [<__main__.Puzzle object at 0x7f9c8469a880> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469a340> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8469a3a0> 'up']
#  [<__main__.Puzzle object at 0x7f9c8469a730> 'right']
#  [<__main__.Puzzle object at 0x7f9c84695910> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469aee0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8469aeb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469a910> 'down']
#  [<__main__.Puzzle object at 0x7f9c8469a790> 'left']
#  [<__main__.Puzzle object at 0x7f9c84697c70> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a0fa0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469af10> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469ad30> 'down']
#  [<__main__.Puzzle object at 0x7f9c8469e3a0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84692dc0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84695970> 'down']
#  [<__main__.Puzzle object at 0x7f9c84697be0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a0ca0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84695910> 'down']
#  [<__main__.Puzzle object at 0x7f9c846a0fd0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469a340> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a0a00> 'left']
#  [<__main__.Puzzle object at 0x7f9c846a0970> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a09a0> 'down']
#  [<__main__.Puzzle object at 0x7f9c84684a90> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a0fd0> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469aee0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8469ea60> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c84697c70> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a0250> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a0d00> 'down']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a0130> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a09a0> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a2f10> 'left']
#  [<__main__.Puzzle object at 0x7f9c846a0190> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8469eeb0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84684a90> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469e520> 'down']
#  [<__main__.Puzzle object at 0x7f9c84697c70> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a2be0> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a09a0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469e2e0> 'down']
#  [<__main__.Puzzle object at 0x7f9c846a0190> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a0fa0> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a2c40> 'down']
#  [<__main__.Puzzle object at 0x7f9c846923a0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a6c40> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a6f40> 'left']
#  [<__main__.Puzzle object at 0x7f9c846a6f70> 'down']
#  [<__main__.Puzzle object at 0x7f9c846a09a0> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a2c40> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469aa30> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469a790> 'down']
#  [<__main__.Puzzle object at 0x7f9c84692430> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8469a970> 'down']
#  [<__main__.Puzzle object at 0x7f9c846a6d30> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a09a0> 'up']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8469a9d0> 'right']
#  [<__main__.Puzzle object at 0x7f9c84692640> 'up']
#  [<__main__.Puzzle object at 0x7f9c8469a760> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a2370> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a6700> 'right']
#  [False False]
#  [False False]]
# Movement not allowed!
# Movement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a67f0> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a6e80> 'right']
#  [<__main__.Puzzle object at 0x7f9c846923a0> 'left']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a8fd0> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a2370> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a8dc0> 'left']
#  [<__main__.Puzzle object at 0x7f9c8469a790> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c8469ac40> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a87c0> 'left']
#  [<__main__.Puzzle object at 0x7f9c846a8760> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a6cd0> 'down']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846ab6d0> 'left']
#  [<__main__.Puzzle object at 0x7f9c846a6ac0> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a6fd0> 'down']
#  [<__main__.Puzzle object at 0x7f9c8469a790> 'up']]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a6790> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a09a0> 'left']
#  [<__main__.Puzzle object at 0x7f9c846a6cd0> 'down']
#  [<__main__.Puzzle object at 0x7f9c846a6ca0> 'up']]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a6f70> 'right']
#  [<__main__.Puzzle object at 0x7f9c8469a790> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a8e80> 'down']
#  [False False]]
# Movement not allowed!
# MOvement not allowed!
# Movement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a86a0> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a8760> 'right']
#  [False False]
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846a8f10> 'up']
#  [<__main__.Puzzle object at 0x7f9c846a6e20> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a20a0> 'down']
#  [False False]]
# MOvement not allowed!
# MOvement not allowed!
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846adbe0> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a0190> 'down']
#  [<__main__.Puzzle object at 0x7f9c846a6eb0> 'up']
#  [False False]]
# Child Goal List:  [[<__main__.Puzzle object at 0x7f9c846ab910> 'right']
#  [<__main__.Puzzle object at 0x7f9c846a6f40> 'left']
#  [<__main__.Puzzle object at 0x7f9c846a8670> 'down']
#  [<__main__.Puzzle object at 0x7f9c846a20a0> 'up']]

# %%
s_obj.movements
# Out:
# [['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['left'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['right'],
#  ['down'],
#  ['down'],
#  ['right'],
#  ['up'],
#  ['right'],
#  ['up'],
#  ['left'],
#  ['left'],
#  ['up'],
#  ['up'],
#  ['up'],
#  ['right'],
#  ['right']]

# %%
s_obj.puzzle.show_matrix()
# Out:
# |012|
# |345|
# |678|
